# %%
import videodataset
from model.model_factory import Model

import numpy as np
import matplotlib.pyplot as plt
import argparse
import math
import random
import os
import cv2
from tqdm import tqdm

import torch
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# ### I / O parameter

# %%
def process_command():
    parser = argparse.ArgumentParser()
    
    parser.add_argument('--dataset_name', default='vimeo90K')
    parser.add_argument('--valid_data_paths', default='videolist/Vimeo90K/test_list.txt')
    parser.add_argument('--gen_frm_dir', default='../MVFI_output/results/test')
    parser.add_argument('--model_name', default='BiLSTM')
    parser.add_argument('--seq_length', default=7, type=int)
    parser.add_argument('--img_size', default=256, type=int)
    parser.add_argument('--img_channel', default=3, type=int)
    parser.add_argument('--num_hidden', default='64,64,64,64')
    parser.add_argument('--filter_size', default=5, type=int)
    parser.add_argument('--stride', default=1, type=int)
    parser.add_argument('--patch_size', default=4, type=int)
    parser.add_argument('--batch_size', default=32, type=int)
    parser.add_argument('--LSTM_pretrained', default='')
    parser.add_argument('--lr', default=0.001, type=float)
    parser.add_argument('--loss', default='L1+L2')
    
    return parser.parse_args(args=[
        '--dataset_name', 'vimeo90K',
        '--valid_data_paths', 'videolist/Vimeo90K/test_list.txt',
        '--gen_frm_dir', '../MVFI_output/results/test',
        '--model_name', 'BiLSTM',
        '--seq_length', '23',
        '--img_size', '224',
        '--img_channel', '3',
        '--num_hidden', '32,32,32,32',
        '--filter_size', '5',
        '--stride', '1',
        '--patch_size', '4',
        '--batch_size', '32',
        '--LSTM_pretrained', '',
        '--lr', '0.001',
        '--loss', 'L1+L2'
    ])
    
args = process_command()

# %% [markdown]
# ### Loading LSTM model

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print("Loading LSTM model...", end='')   
LSTM = Model(args, device)
print("...OK")
# Out:
# Loading LSTM model......OK

# %%
# get video list from video_list_paths
with open(args.valid_data_paths, 'r') as f:
    valid_video_list = [line.strip() for line in f.readlines()]

# %%
checkpoint_path = 'checkpoint_299.tar'
checkpoint = torch.load(checkpoint_path)
model_state_dict = checkpoint['model_state_dict']
optimizer_state_dict = checkpoint['optimizer_state_dict']
pretrained_epoch = checkpoint['epoch']
mask_probability = checkpoint['mask_probability']
# model loading weight
LSTM.load_checkpoint(model_state_dict, optimizer_state_dict)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-c5beffe7e843> in <module>
#       6 mask_probability = checkpoint['mask_probability']
#       7 # model loading weight
# ----> 8 LSTM.load_checkpoint(model_state_dict, optimizer_state_dict)
#
# ~/multi-interpolation-pytorch/model/model_factory.py in load_checkpoint(self, model_state_dict, optimizer_state_dict)
#     155
#     156     def load_checkpoint(self, model_state_dict, optimizer_state_dict):
# --> 157         self.network.load_state_dict(model_state_dict)
#     158         self.optimizer.load_state_dict(optimizer_state_dict)
#     159
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#    1222         if len(error_msgs) > 0:
#    1223             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# -> 1224                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    1225         return _IncompatibleKeys(missing_keys, unexpected_keys)
#    1226
#
# RuntimeError: Error(s) in loading state_dict for DataParallel:
# 	size mismatch for module.lstm_fw.0.conv_x.0.weight: copying a param with shape torch.Size([448, 48, 5, 5]) from checkpoint, the shape in current model is torch.Size([224, 48, 5, 5]).
# 	size mismatch for module.lstm_fw.0.conv_x.0.bias: copying a param with shape torch.Size([448]) from checkpoint, the shape in current model is torch.Size([224]).
# 	size mismatch for module.lstm_fw.0.conv_x.1.weight: copying a param with shape torch.Size([448, 56, 56]) from checkpoint, the shape in current model is torch.Size([224, 56, 56]).
# 	size mismatch for module.lstm_fw.0.conv_x.1.bias: copying a param with shape torch.Size([448, 56, 56]) from checkpoint, the shape in current model is torch.Size([224, 56, 56]).
# 	size mismatch for module.lstm_fw.0.conv_h.0.weight: copying a param with shape torch.Size([256, 64, 5, 5]) from checkpoint, the shape in current model is torch.Size([128, 32, 5, 5]).
# 	size mismatch for module.lstm_fw.0.conv_h.0.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for module.lstm_fw.0.conv_h.1.weight: copying a param with shape torch.Size([256, 56, 56]) from checkpoint, the shape in current model is torch.Size([128, 56, 56]).
# 	size mismatch for module.lstm_fw.0.conv_h.1.bias: copying a param with shape torch.Size([256, 56, 56]) from checkpoint, the shape in current model is torch.Size([128, 56, 56]).
# 	size mismatch for module.lstm_fw.0.conv_m.0.weight: copying a param with shape torch.Size([192, 64, 5, 5]) from checkpoint, the shape in current model is torch.Size([96, 32, 5, 5]).
# 	size mismatch for module.lstm_fw.0.conv_m.0.bias: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([96]).
# 	size mismatch for module.lstm_fw.0.conv_m.1.weight: copying a param with shape torch.Size([192, 56, 56]) from checkpoint, the shape in current model is torch.Size([96, 56, 56]).
# 	size mismatch for module.lstm_fw.0.conv_m.1.bias: copying a param with shape torch.Size([192, 56, 56]) from checkpoint, the shape in current model is torch.Size([96, 56, 56]).
# 	size mismatch for module.lstm_fw.0.conv_o.0.weight: copying a param with shape torch.Size([64, 128, 5, 5]) from checkpoint, the shape in current model is torch.Size([32, 64, 5, 5]).
# 	size mismatch for module.lstm_fw.0.conv_o.0.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([32]).
# 	size mismatch for module.lstm_fw.0.conv_o.1.weight: copying a param with shape torch.Size([64, 56, 56]) from checkpoint, the shape in current model is torch.Size([32, 56, 56]).
# 	size mismatch for module.lstm_fw.0.conv_o.1.bias: copying a param with shape torch.Size([64, 56, 56]) from checkpoint, the shape in current model is torch.Size([32, 56, 56]).
# 	size mismatch for module.lstm_fw.0.conv_last.weight: copying a param with shape torch.Size([64, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([32, 64, 1, 1]).
# 	size mismatch for module.lstm_fw.0.conv_last.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([32]).
# 	size mismatch for module.lstm_bw.0.conv_x.0.weight: copying a param with shape torch.Size([448, 48, 5, 5]) from checkpoint, the shape in current model is torch.Size([224, 48, 5, 5]).
# 	size mismatch for module.lstm_bw.0.conv_x.0.bias: copying a param with shape torch.Size([448]) from checkpoint, the shape in current model is torch.Size([224]).
# 	size mismatch for module.lstm_bw.0.conv_x.1.weight: copying a param with shape torch.Size([448, 56, 56]) from checkpoint, the shape in current model is torch.Size([224, 56, 56]).
# 	size mismatch for module.lstm_bw.0.conv_x.1.bias: copying a param with shape torch.Size([448, 56, 56]) from checkpoint, the shape in current model is torch.Size([224, 56, 56]).
# 	size mismatch for module.lstm_bw.0.conv_h.0.weight: copying a param with shape torch.Size([256, 64, 5, 5]) from checkpoint, the shape in current model is torch.Size([128, 32, 5, 5]).
# 	size mismatch for module.lstm_bw.0.conv_h.0.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for module.lstm_bw.0.conv_h.1.weight: copying a param with shape torch.Size([256, 56, 56]) from checkpoint, the shape in current model is torch.Size([128, 56, 56]).
# 	size mismatch for module.lstm_bw.0.conv_h.1.bias: copying a param with shape torch.Size([256, 56, 56]) from checkpoint, the shape in current model is torch.Size([128, 56, 56]).
# 	size mismatch for module.lstm_bw.0.conv_m.0.weight: copying a param with shape torch.Size([192, 64, 5, 5]) from checkpoint, the shape in current model is torch.Size([96, 32, 5, 5]).
# 	size mismatch for module.lstm_bw.0.conv_m.0.bias: copying a param with shape torch.Size([192]) from checkpoint, the shape in current model is torch.Size([96]).
# 	size mismatch for module.lstm_bw.0.conv_m.1.weight: copying a param with shape torch.Size([192, 56, 56]) from checkpoint, the shape in current model is torch.Size([96, 56, 56]).
# 	size mismatch for module.lstm_bw.0.conv_m.1.bias: copying a param with shape torch.Size([192, 56, 56]) from checkpoint, the shape in current model is torch.Size([96, 56, 56]).
# 	size mismatch for module.lstm_bw.0.conv_o.0.weight: copying a param with shape torch.Size([64, 128, 5, 5]) from checkpoint, the shape in current model is torch.Size([32, 64, 5, 5]).
# 	size mismatch for module.lstm_bw.0.conv_o.0.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([32]).
# 	size mismatch for module.lstm_bw.0.conv_o.1.weight: copying a param with shape torch.Size([64, 56, 56]) from checkpoint, the shape in current model is torch.Size([32, 56, 56]).
# 	size mismatch for module.lstm_bw.0.conv_o.1.bias: copying a param with shape torch.Size([64, 56, 56]) from checkpoint, the shape in current model is torch.Size([32, 56, 56]).
# 	size mismatch for module.lstm_bw.0.conv_last.weight: copying a param with shape torch.Size([64, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([32, 64, 1, 1]).
# 	size mismatch for module.lstm_bw.0.conv_last.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([32]).
# 	size mismatch for module.hidden_concat_conv_l2.weight: copying a param with shape torch.Size([32, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([32, 64, 1, 1]).
# 	size mismatch for module.mem_concat_conv_l2.weight: copying a param with shape torch.Size([32, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([32, 64, 1, 1]).
# 	size mismatch for module.hidden_concat_conv_gen.weight: copying a param with shape torch.Size([64, 64, 1, 1]) from checkpoint, the shape in current model is torch.Size([32, 64, 1, 1]).
# 	size mismatch for module.hidden_concat_conv_gen.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([32]).
# 	size mismatch for module.conv_last.weight: copying a param with shape torch.Size([48, 64, 1, 1]) from checkpoint, the shape in current model is torch.Size([48, 32, 1, 1]).
# 	size mismatch for module.ghu.conv_z.0.weight: copying a param with shape torch.Size([128, 64, 5, 5]) from checkpoint, the shape in current model is torch.Size([64, 32, 5, 5]).
# 	size mismatch for module.ghu.conv_z.0.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([64]).
# 	size mismatch for module.ghu.conv_z.1.weight: copying a param with shape torch.Size([128, 56, 56]) from checkpoint, the shape in current model is torch.Size([64, 56, 56]).
# 	size mismatch for module.ghu.conv_z.1.bias: copying a param with shape torch.Size([128, 56, 56]) from checkpoint, the shape in current model is torch.Size([64, 56, 56]).
# 	size mismatch for module.ghu.conv_x.0.weight: copying a param with shape torch.Size([128, 64, 5, 5]) from checkpoint, the shape in current model is torch.Size([64, 32, 5, 5]).
# 	size mismatch for module.ghu.conv_x.0.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([64]).
# 	size mismatch for module.ghu.conv_x.1.weight: copying a param with shape torch.Size([128, 56, 56]) from checkpoint, the shape in current model is torch.Size([64, 56, 56]).
# 	size mismatch for module.ghu.conv_x.1.bias: copying a param with shape torch.Size([128, 56, 56]) from checkpoint, the shape in current model is torch.Size([64, 56, 56]).

# %%
valid_dataset = videodataset.VideoDataset(valid_video_list, args.dataset_name,
                                          seq_length=args.seq_length, 
                                          img_size=args.img_size, 
                                          img_channel=args.img_channel, 
                                          mode="valid", 
                                          mask_probability=0)
valid_loader = DataLoader(dataset=valid_dataset, batch_size=args.batch_size, shuffle=False, num_workers=12)

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10, 10))
for vid_path, seq, seq_gt in valid_loader:
    print(np.shape(seq))
    imgs = seq[0]
    for i, img in enumerate(imgs):
        plt.subplot(1, 7, i+1)
        plt.imshow(img.permute(1, 2, 0))
    break
# Out:
# torch.Size([32, 7, 3, 224, 224])

# %%
import imageio
filepath = "../data/vimeo90K_Done/3384/0010"
filenames = []
for i in range(30):
    filenames.append(os.path.join(filepath, '{}.png'.format(i+1)))

images = []
for filename in filenames:
    images.append(imageio.imread(filename))
imageio.mimsave('test.gif', images)

# %%
import shutil
shutil.rmtree("../data/vimeo90K_Done/1204/0004")

# %%
print("Testing...")
all_psnr = []
all_ssim = []
for vid_path, seq, seq_gt in valid_loader:
    batch_psnr, batch_ssim = LSTM.test(vid_path, args.gen_frm_dir, seq, seq_gt, 0)

# %%
import os
import matplotlib.pyplot as plt

# %%
path = '../data/vimeo90K_Done/3197/0031'
for i in range(3):
    ipath = os.path.join(path, '{}.png'.format(i+1))
    img = plt.imread(ipath)
    plt.subplot(1, 3, i+1)
    plt.imshow(img)

# %%
import shutil
shutil.rmtree(path)
